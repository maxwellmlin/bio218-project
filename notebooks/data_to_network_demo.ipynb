# %% [markdown]
# ## This is a basic demo of going from data to a network using the functions in utilities.py

# %% [markdown]
# The outputs of each cell has been left so you can view what the outputs look like. Feel free to rerun the cells though!

# %%
# You must inlcude and run this code in any notebook
# %run -i ../src/utilities.py

# %%
# Run this function as is to view the available data
view_data_toc()
# Out:
#                                                           Process  \
# Organism
# Saccharomyces cerevisiae                               Cell Cycle
# Saccharomyces cerevisiae                               Cell Cycle
# Saccharomyces cerevisiae                               Cell Cycle
# Saccharomyces cerevisiae                               Cell Cycle
# Saccharomyces cerevisiae                               Cell Cycle
# Saccharomyces cerevisiae                               Cell Cycle
# Saccharomyces cerevisiae                               Cell Cycle
# Saccharomyces cerevisiae                               Cell Cycle
# Saccharomyces cerevisiae                               Cell Cycle
# Saccharomyces cerevisiae                               Cell Cycle
# Saccharomyces cerevisiae                               Cell Cycle
# Saccharomyces cerevisiae                               Cell Cycle
# Saccharomyces cerevisiae                               Cell Cycle
# Cryptococcus neoformans                                Cell Cycle
# Homo sapiens                                           Cell Cycle
# Homo sapiens                                           Cell Cycle
# Homo sapiens                                           Cell Cycle
# Ophiocordyceps kimflemingiae                            Circadian
# Ophiocordyceps kimflemingiae                            Circadian
# Phaeodactylum tricornutum                               Circadian
# Mus musculus                                            Circadian
# Mus musculus                                            Circadian
# Mus musculus                                            Circadian
# Arabidopsis thaliana                                    Circadian
# Arabidopsis thaliana                                    Circadian
# Kalanchoe fedtschenkoi                                  Circadian
# Kalanchoe fedtschenkoi                                  Circadian
# Plasmodium falciparum         Intraerythrocytic Development Cycle
# Plasmodium vivax              Intraerythrocytic Development Cycle
# Plasmodium vivax              Intraerythrocytic Development Cycle
#
#                                                                       Condition  \
# Organism
# Saccharomyces cerevisiae                                  Wild-type replicate 1
# Saccharomyces cerevisiae                                  Wild-type replicate 2
# Saccharomyces cerevisiae                                              Wild-type
# Saccharomyces cerevisiae                            No APC activity replicate 1
# Saccharomyces cerevisiae                            No APC activity replicate 2
# Saccharomyces cerevisiae                     No cyclin-CDK activity replicate 1
# Saccharomyces cerevisiae                     No cyclin-CDK activity replicate 2
# Saccharomyces cerevisiae            DNA Damage Checkpoint activated replicate 1
# Saccharomyces cerevisiae            DNA Damage Checkpoint activated replicate 2
# Saccharomyces cerevisiae      Perturbed DNA Damage Checkpoint activated + no...
# Saccharomyces cerevisiae      Perturbed DNA Damage Checkpoint activated + no...
# Saccharomyces cerevisiae        Spindle Assembly Checkout activated replicate 1
# Saccharomyces cerevisiae        Spindle Assembly Checkout activated replicate 2
# Cryptococcus neoformans                                               Wild-type
# Homo sapiens                                                     K562 cell line
# Homo sapiens                                                     HeLa cell line
# Homo sapiens                                                    HeCat cell line
# Ophiocordyceps kimflemingiae                                         light-dark
# Ophiocordyceps kimflemingiae                                          dark-dark
# Phaeodactylum tricornutum                                            light-dark
# Mus musculus                                                   dark-dark Liver
# Mus musculus                                                  dark-dark Kidney
# Mus musculus                                                    dark-dark Lung
# Arabidopsis thaliana                                                 light-dark
# Arabidopsis thaliana                                                light-light
# Kalanchoe fedtschenkoi                                               light-dark
# Kalanchoe fedtschenkoi                                              light-light
# Plasmodium falciparum                                              in vitro 3D7
# Plasmodium vivax                                         ex vivo Participant 08
# Plasmodium vivax                                         ex vivo Participant 09
#
#                              Sampling Frequency Sampling Duration  \
# Organism
# Saccharomyces cerevisiae                 16 min           254 min
# Saccharomyces cerevisiae                 16 min           262 min
# Saccharomyces cerevisiae                  5 min           245 min
# Saccharomyces cerevisiae                 20 min           300 min
# Saccharomyces cerevisiae                 20 min           360 min
# Saccharomyces cerevisiae                 16 min           262 min
# Saccharomyces cerevisiae                 16 min           254 min
# Saccharomyces cerevisiae                 Uneven           260 min
# Saccharomyces cerevisiae                 Uneven           260 min
# Saccharomyces cerevisiae                 18 min           360 min
# Saccharomyces cerevisiae                 18 min           360 min
# Saccharomyces cerevisiae                 15 min           245 min
# Saccharomyces cerevisiae                 15 min           245 min
# Cryptococcus neoformans                  10 min           230 min
# Homo sapiens                               2 hr             48 hr
# Homo sapiens                               1 hr             47 hr
# Homo sapiens                               3 hr             33 hr
# Ophiocordyceps kimflemingiae               4 hr             48 hr
# Ophiocordyceps kimflemingiae               4 hr             48 hr
# Phaeodactylum tricornutum                Uneven             27 hr
# Mus musculus                               2 hr             48 hr
# Mus musculus                               2 hr             48 hr
# Mus musculus                               2 hr             48 hr
# Arabidopsis thaliana                       4 hr             48 hr
# Arabidopsis thaliana                       4 hr             48 hr
# Kalanchoe fedtschenkoi                     2 hr             48 hr
# Kalanchoe fedtschenkoi                     2 hr             48 hr
# Plasmodium falciparum                      3 hr             60 hr
# Plasmodium vivax                           3 hr             48 hr
# Plasmodium vivax                           3 hr             48 hr
#
#                                                    Dataset        Type  \
# Organism
# Saccharomyces cerevisiae      Scerevisiae_WT_r1_Microarray  Microarray
# Saccharomyces cerevisiae      Scerevisiae_WT_r2_Microarray  Microarray
# Saccharomyces cerevisiae                Scerevisiae_RNAseq      RNAseq
# Saccharomyces cerevisiae              Scerevisiae_noAPC_r1  Microarray
# Saccharomyces cerevisiae              Scerevisiae_noAPC_r2  Microarray
# Saccharomyces cerevisiae              Scerevisiae_noCDK_r1  Microarray
# Saccharomyces cerevisiae              Scerevisiae_noCDK_r2  Microarray
# Saccharomyces cerevisiae                Scerevisiae_DRC_r1  Microarray
# Saccharomyces cerevisiae                Scerevisiae_DRC_r2  Microarray
# Saccharomyces cerevisiae         Scerevisiae_xDRC_noAPC_r1  Microarray
# Saccharomyces cerevisiae         Scerevisiae_xDRC_noAPC_r2  Microarray
# Saccharomyces cerevisiae               Scerevisiae_SpAC_r1  Microarray
# Saccharomyces cerevisiae               Scerevisiae_SpAC_r2  Microarray
# Cryptococcus neoformans                 Cneoformans_RNAseq      RNAseq
# Homo sapiens                                 Hsapiens_K562      RNAseq
# Homo sapiens                                 Hsapiens_HeLa  Microarray
# Homo sapiens                                Hsapiens_HeCat  Microarray
# Ophiocordyceps kimflemingiae        Okimflemingiae_DD_RPKM      RNAseq
# Ophiocordyceps kimflemingiae        Okimflemingiae_LD_RPKM      RNAseq
# Phaeodactylum tricornutum                  Ptricornutum_LD  Microarray
# Mus musculus                          Mmusculus_liver_DDHC  Microarray
# Mus musculus                         Mmusculus_kidney_DDHC  Microarray
# Mus musculus                           Mmusculus_lung_DDHC  Microarray
# Arabidopsis thaliana                          Athaliana_LD  Microarray
# Arabidopsis thaliana                          Athaliana_LL  Microarray
# Kalanchoe fedtschenkoi                    Kfedtschenkoi_LD      RNAseq
# Kalanchoe fedtschenkoi                    Kfedtschenkoi_LL      RNAseq
# Plasmodium falciparum                      Pfalciparum_3D7      RNAseq
# Plasmodium vivax                                 Pvivax_08      RNAseq
# Plasmodium vivax                                 Pvivax_09      RNAseq
#
#                                   PMID
# Organism
# Saccharomyces cerevisiae      18463633
# Saccharomyces cerevisiae      18463633
# Saccharomyces cerevisiae      27918582
# Saccharomyces cerevisiae      25200947
# Saccharomyces cerevisiae      25200947
# Saccharomyces cerevisiae      18463633
# Saccharomyces cerevisiae      18463633
# Saccharomyces cerevisiae      25200947
# Saccharomyces cerevisiae      25200947
# Saccharomyces cerevisiae      25200947
# Saccharomyces cerevisiae      25200947
# Saccharomyces cerevisiae      25200947
# Saccharomyces cerevisiae      25200947
# Cryptococcus neoformans       27918582
# Homo sapiens                       NaN
# Homo sapiens                  12058064
# Homo sapiens                  23325852
# Ophiocordyceps kimflemingiae  29099875
# Ophiocordyceps kimflemingiae  29099875
# Phaeodactylum tricornutum     23209127
# Mus musculus                  25349387
# Mus musculus                  25349388
# Mus musculus                  25349389
# Arabidopsis thaliana          18248097
# Arabidopsis thaliana          18248097
# Kalanchoe fedtschenkoi        29196618
# Kalanchoe fedtschenkoi        29196618
# Plasmodium falciparum         32409472
# Plasmodium vivax                   NaN
# Plasmodium vivax                   NaN

# %% [markdown]
# ### Loading data in and how to check and handle duplicate gene names

# %%
# This function loads a dataset into a datafame. The dataset name is taken from the "Dataset" column of the Dataset Table of Contents (printed above ^^)
data_df = load_dataset('Scerevisiae_WT1_Microarray')
data_df.head() # <-- adding .head() allows you to view the top few rows of a dataframe
# Out:
#                       30           46           62           78           94  \
# time_points
# FOX2         3176.837656  1839.948678  1248.714962   896.914709   861.681282
# YDL157C      2758.241870  3513.795607  5066.365684  6996.471392  8107.569571
# PCL6         1658.280545   891.561505   961.179614   898.165328   888.969974
# PKP2          893.195718   375.650229   259.013841   271.887341   316.900588
# PHO8         2377.729994  1459.913001  1150.910362  2012.029694  2687.383431
#
#                      110          126          142          158          174  \
# time_points
# FOX2          918.854521   925.588921   927.705403   968.911059  1032.305135
# YDL157C      7977.403961  6381.621673  5044.680303  5041.913622  6031.505741
# PCL6          931.729315  1057.853377  1165.162685  1234.892702  1166.776615
# PKP2          317.933060   354.225045   406.931381   435.892101   359.524322
# PHO8         2224.502378  1903.953327  2048.862330  2608.718570  2992.434776
#
#                      190          206          222          238          254
# time_points
# FOX2          982.675859   987.949172   940.685429   957.905302  1009.043208
# YDL157C      6498.590873  6459.858522  6163.031609  5978.819127  5792.091678
# PCL6         1103.191922  1075.442704  1222.253716  1173.119347  1235.258111
# PKP2          373.124800   379.755595   348.730460   407.141179   372.555663
# PHO8         2837.817869  2542.630140  2753.913194  2981.628434  3426.344393

# %%
# Use this function on your dataframe to see if the data contains any duplicate gene names. Having duplicate gene names will cause headaches later in your analyses.
duplicate_check(data_df)
# Out:
# This dataset has duplicate gene names. This needs to be corrected.
# You can either drop duplicates or relabel duplicates.
# -- Use remove_duplicates() to only keep the duplicate with either the highest gene expression at any time point or highest average gene expression.
# -- Use relabel_duplicates() to append "dupN" to each duplicate gene name, where N is an integer.
# False

# %%
# I am choosing to remove duplicates by only keeping the duplicate with the highest max gene expression.
data_nodups_df = remove_duplicates(data_df, 'max')

# %%
# No duplicates!
duplicate_check(data_nodups_df)
# Out:
# This dataset has no duplicate gene names.
# True

# %% [markdown]
# ### Running periodicity algorithms on a dataset

# %%
# For demo purposes, I am reducing the amount of genes I will analyze as some algorithms take awhile to run depending on the number of genes being analyzed.
demo_df = data_nodups_df.loc[['SWI4','NRM1', 'MCM1', 'YOX1', 'FOX2', 'PLM2', 'DAT1', 'FOL2', 'SWI5', 'ACE2', 'PDH1', 'ACT1', 'NDE2'],:]

# %%
# I will run all the periodicity algorithms on the demo dataframe. For this yeast cell cycle dataset, I think the actual cell cycle period is between 75 minutes and 100 minutes
# so I will set the minimum period to 75 and the maximum period to 100. I want test periods between these two at five minute intervals so I will set the period step to 5. 
# I also think the average period is around 95 minutes so I will set the average period as such. Since I am using yeast microarry data and this is a demo, I want my results to contain
# this information so I set filename to 'yeast_ma_demo'. This name will be used in the naming of results file and directory names. You can use anything you like.
pyjtk_results, pydl_results, ls_results = run_periodicity(demo_df, 75, 100, 5, 95, 'yeast_ma_demo', return_results=False)
# Out:
# Running periodicity algorithms
# Running pyJTK
# -- Running pyJTK on dataset, testing period(s) of 75 80 85 90 95 100
# -- Command used: python ../src/pyjtk/pyjtk.py ../tmp/yeast_ma_demo__20211006174423.tsv -T 75 80 85 90 95 100 -o ../results/yeast_ma_demo__20211006174423_pyjtk_p75-100s5.tsv
# -- Results saved as yeast_ma_demo__20211006174423_pyjtk_p75-100s5.tsv in the results directory
# Running pyDL
# -- Running pyDL on dataset, testing a period of 95
# -- Command used: mpiexec -n 2 python ../src/pydl/pydl.py ../tmp/yeast_ma_demo__20211006174423.tsv -T 95 -o ../results/yeast_ma_demo__20211006174424_pydl_p95.tsv -r 1 -p 1 -l True -v False
# -- Results saved as yeast_ma_demo__20211006174424_pydl_p95.tsv in the results directory
# Running Lomb-Scargle
# -- Running Lomb-Scargle on dataset, testing periods 75-100 at a frequency of 4 minutes
# -- Command used: python ../src/ls/_run_ls_params.py ../tmp/yeast_ma_demo__20211006174425.tsv ../results 75 100 4 minutes
# -- Results saved in yeast_ma_demo__20211006174425_ls_p75-100f4 in the results directory

# %% [markdown]
# **NOTE: Each periodicity algorithm can be run individually on a dataset.**

# %% [markdown]
# ### Visualizing gene expression

# %%
# I would like to view the top 6 genes that pyJTK has ranked as the most periodic in a heatmap. I want to ordered genes based on their peak expression BEFORE 96 minutes.
plot_heatmap(demo_df, pyjtk_results, 96, 'p-value', top_genes=6)
# Out:
# Loading periodicity results

# %%
# I also want to inspect their gene expression profiles in a line graph.
# I just create a gene list
gene_list = get_genelist_from_top_n_genes(pyjtk_results, 'p-value', 6)
# I then supply that list, along with the dataframe, to plot the line graphs. I want to normalize the expression of each gene via z-score transformation.
plot_linegraphs_from_gene_list(demo_df, gene_list, norm_data=True)
# Out:
# Loading periodicity results

# %% [markdown]
# ### Applying LEMpy and visualizing networks

# %%
# I now want to use LEM to infer regulatory relationships between a set of regulators and targets.
# For the sake of demoing, I have created arbitrary gene lists of targets, repressors and activators.
# Note, these list can overlap in what genes they contain. That is prefectly fine.
targets_list = ['SWI4','NRM1', 'MCM1', 'YOX1', 'FOX2', 'PLM2',  'SWI5', 'ACE2', 'ACT1']
repressors_list = ['SWI4','NRM1', 'MCM1', 'YOX1']
activators_list = ['YOX1', 'FOX2', 'PLM2',  'SWI5', 'ACE2', 'ACT1']

# %%
# LEMpy requires a dataset, lists of targets, repressors and activators, and something to name the results. Here I used the same filename as before in the periodicity section.
all_scores_df = run_lem(demo_df, targets_list, repressors_list, activators_list, 'yeast_ma_demo')
# Out:
# -- Running LEMpy on dataset ../tmp/tmp_20211006175949.tsv
# -- Command used: mpiexec -n 2 python ../src/lempy/lempy.py ../results/yeast_ma_demo__20211006175949_lempy/lempy_20211006175949_config.txt
# -- Results saved in ../results/yeast_ma_demo__20211006175949_lempy

# %%
# LEMpy's output is a ranking of all the regulatory relationships (or edges) but I am only interested in the top 10 edges for building a network.
# The network produced is interactive so you can move the nodes/genes around. If you know the order of how the genes are expressed, try rearranging
# the nodes in the network in the same order!
make_top_edge_network(all_scores_df, 10)
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'cola'}, cytoscape_style=[{'selector': 'node', 'style': {'content': …
